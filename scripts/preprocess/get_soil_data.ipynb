# %%
from owslib.wcs import WebCoverageService
import rasterio
import numpy as np
import os
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load data

# %%
bbox = (553915.4983940837, 5112351.329324091, 578415.4983940837, 5137851.329324091)
crs='urn:ogc:def:crs:EPSG::32632'
resx = 250
resy = 250
format = 'GEOTIFF_INT16'

# %%
# importing the WCS data.
clay_wcs = WebCoverageService('http://maps.isric.org/mapserv?map=/map/clay.map', version='1.0.0')
sand_wcs = WebCoverageService('http://maps.isric.org/mapserv?map=/map/sand.map', version='1.0.0')
silt_wcs = WebCoverageService('http://maps.isric.org/mapserv?map=/map/silt.map', version='1.0.0')
bdod_wcs = WebCoverageService('http://maps.isric.org/mapserv?map=/map/bdod.map', version='1.0.0')

# path to ISRIC tif
path_in = '../../data/prepareddata/SG_VM_2022_ISRIC/'

# load and save clay 0-5cm
response = clay_wcs.getCoverage(identifier='clay_0-5cm_mean', crs=crs, bbox=bbox, resx=resx, resy=resy, format=format)
with open( path_in + 'clay_0-5_mean.tif', 'wb') as file:
    file.write(response.read())

# load clay 5-15cm
response = clay_wcs.getCoverage(identifier='clay_5-15cm_mean', crs=crs, bbox=bbox, resx=resx, resy=resy, format=format)
with open(path_in + 'clay_5-15_mean.tif', 'wb') as file:
    file.write(response.read())

# load clay 15-30cm
response = clay_wcs.getCoverage(identifier='clay_15-30cm_mean', crs=crs, bbox=bbox, resx=resx, resy=resy, format=format)
with open(path_in + 'clay_15-30_mean.tif', 'wb') as file:
    file.write(response.read())

# load clay 30-60cm
response = clay_wcs.getCoverage(identifier='clay_30-60cm_mean', crs=crs, bbox=bbox, resx=resx, resy=resy, format=format)
with open(path_in + 'clay_30-60_mean.tif', 'wb') as file:
    file.write(response.read())

# load clay 60-100cm
response = clay_wcs.getCoverage(identifier='clay_60-100cm_mean', crs=crs, bbox=bbox, resx=resx, resy=resy, format=format)
with open(path_in + 'clay_60-100_mean.tif', 'wb') as file:
    file.write(response.read())

# load clay 100-200cm
response = clay_wcs.getCoverage(identifier='clay_100-200cm_mean', crs=crs, bbox=bbox, resx=resx, resy=resy, format=format)
with open(path_in + 'clay_100-200_mean.tif', 'wb') as file:
    file.write(response.read())

# load and save sand 0-5cm
response = sand_wcs.getCoverage(identifier='sand_0-5cm_mean', crs=crs, bbox=bbox, resx=resx, resy=resy, format=format)
with open(path_in + 'sand_0-5_mean.tif', 'wb') as file:
    file.write(response.read())

# load sand 5-15cm
response = sand_wcs.getCoverage(identifier='sand_5-15cm_mean', crs=crs, bbox=bbox, resx=resx, resy=resy, format=format)
with open(path_in + 'sand_5-15_mean.tif', 'wb') as file:
    file.write(response.read())

# load sand 15-30cm
response = sand_wcs.getCoverage(identifier='sand_15-30cm_mean', crs=crs, bbox=bbox, resx=resx, resy=resy, format=format)
with open(path_in + 'sand_15-30_mean.tif', 'wb') as file:
    file.write(response.read())

# load sand 30-60cm
response = sand_wcs.getCoverage(identifier='sand_30-60cm_mean', crs=crs, bbox=bbox, resx=resx, resy=resy, format=format)
with open(path_in + 'sand_30-60_mean.tif', 'wb') as file:
    file.write(response.read())

# load sand 60-100cm
response = sand_wcs.getCoverage(identifier='sand_60-100cm_mean', crs=crs, bbox=bbox, resx=resx, resy=resy, format=format)
with open(path_in + 'sand_60-100_mean.tif', 'wb') as file:
    file.write(response.read())

# load sand 100-200cm
response = sand_wcs.getCoverage(identifier='sand_100-200cm_mean', crs=crs, bbox=bbox, resx=resx, resy=resy, format=format)
with open(path_in + 'sand_100-200_mean.tif', 'wb') as file:
    file.write(response.read())

# load and save silt 0-5cm
response = silt_wcs.getCoverage(identifier='silt_0-5cm_mean', crs=crs, bbox=bbox, resx=resx, resy=resy, format=format)
with open(path_in + 'silt_0-5_mean.tif', 'wb') as file:
    file.write(response.read())

# load silt 5-15cm
response = silt_wcs.getCoverage(identifier='silt_5-15cm_mean', crs=crs, bbox=bbox, resx=resx, resy=resy, format=format)
with open(path_in + 'silt_5-15_mean.tif', 'wb') as file:
    file.write(response.read())

# load silt 15-30cm
response = silt_wcs.getCoverage(identifier='silt_15-30cm_mean', crs=crs, bbox=bbox, resx=resx, resy=resy, format=format)
with open(path_in + 'silt_15-30_mean.tif', 'wb') as file:
    file.write(response.read())

# load silt 30-60cm
response = silt_wcs.getCoverage(identifier='silt_30-60cm_mean', crs=crs, bbox=bbox, resx=resx, resy=resy, format=format)
with open(path_in + 'silt_30-60_mean.tif', 'wb') as file:
    file.write(response.read())

# load silt 60-100cm
response = silt_wcs.getCoverage(identifier='silt_60-100cm_mean', crs=crs, bbox=bbox, resx=resx, resy=resy, format=format)
with open(path_in + 'silt_60-100_mean.tif', 'wb') as file:
    file.write(response.read())

# load silt 100-200cm
response = silt_wcs.getCoverage(identifier='silt_100-200cm_mean', crs=crs, bbox=bbox, resx=resx, resy=resy, format=format)
with open(path_in + 'silt_100-200_mean.tif', 'wb') as file:
    file.write(response.read())

# load and save bdod 0-5cm
response = bdod_wcs.getCoverage(identifier='bdod_0-5cm_mean', crs=crs, bbox=bbox, resx=resx, resy=resy, format=format)
with open(path_in + 'bdod_0-5_mean.tif', 'wb') as file:
    file.write(response.read())

# load bdod 5-15cm
response = bdod_wcs.getCoverage(identifier='bdod_5-15cm_mean', crs=crs, bbox=bbox, resx=resx, resy=resy, format=format)
with open(path_in + 'bdod_5-15_mean.tif', 'wb') as file:
    file.write(response.read())

# load bdod 15-30cm
response = bdod_wcs.getCoverage(identifier='bdod_15-30cm_mean', crs=crs, bbox=bbox, resx=resx, resy=resy, format=format)
with open(path_in + 'bdod_15-30_mean.tif', 'wb') as file:
    file.write(response.read())

# load bdod 30-60cm
response = bdod_wcs.getCoverage(identifier='bdod_30-60cm_mean', crs=crs, bbox=bbox, resx=resx, resy=resy, format=format)
with open(path_in + 'bdod_30-60_mean.tif', 'wb') as file:
    file.write(response.read())

# load bdod 60-100cm
response = bdod_wcs.getCoverage(identifier='bdod_60-100cm_mean', crs=crs, bbox=bbox, resx=resx, resy=resy, format=format)
with open(path_in + 'bdod_60-100_mean.tif', 'wb') as file:
    file.write(response.read())

# load bdod 100-200cm
response = bdod_wcs.getCoverage(identifier='bdod_100-200cm_mean', crs=crs, bbox=bbox, resx=resx, resy=resy, format=format)
with open(path_in + 'bdod_100-200_mean.tif', 'wb') as file:
    file.write(response.read())

# %% [markdown]
# ### Predict parameters with Rosetta

# %% [markdown]
# #### Organize data

# %%
# 0 to 5cm
#clay
clay_0_5 = rasterio.open(path_in + 'clay_0-5_mean.tif')
clay_0_5 = np.reshape(clay_0_5.read(1)/10,-1)

# sand
sand_0_5 = rasterio.open(path_in + 'sand_0-5_mean.tif')
sand_0_5 = np.reshape(sand_0_5.read(1)/10,-1)

# silt
silt_0_5 = rasterio.open(path_in + 'silt_0-5_mean.tif')
silt_0_5 = np.reshape(silt_0_5.read(1)/10,-1)

# bdod
bdod_0_5 = rasterio.open(path_in + 'bdod_0-5_mean.tif')
bdod_0_5 = np.reshape(bdod_0_5.read(1)/100,-1)

input_data_0_5 = np.vstack((clay_0_5,sand_0_5,silt_0_5,bdod_0_5)).T
input_file = path_in + 'input_data_0_5.txt'
output_file = path_in + 'output_data_0_5.txt'
np.savetxt(input_file, input_data_0_5)
np.savetxt(output_file, np.array([0,0]))

# 5 to 15cm
#clay
clay_5_15 = rasterio.open(path_in + 'clay_5-15_mean.tif')
clay_5_15 = np.reshape(clay_5_15.read(1)/10,-1)

# sand
sand_5_15 = rasterio.open(path_in + 'sand_5-15_mean.tif')
sand_5_15 = np.reshape(sand_5_15.read(1)/10,-1)

# silt
silt_5_15 = rasterio.open(path_in + 'silt_5-15_mean.tif')
silt_5_15 = np.reshape(silt_5_15.read(1)/10,-1)

# bdod
bdod_5_15 = rasterio.open(path_in + 'bdod_5-15_mean.tif')
bdod_5_15 = np.reshape(bdod_5_15.read(1)/100,-1)

input_data_5_15 = np.vstack((clay_5_15,sand_5_15,silt_5_15,bdod_5_15)).T
input_file = path_in + 'input_data_5_15.txt'
output_file = path_in + 'output_data_5_15.txt'
np.savetxt(input_file, input_data_5_15)
np.savetxt(output_file, np.array([0,0]))

# 15 to 30cm
#clay
clay_15_30 = rasterio.open(path_in + 'clay_15-30_mean.tif')
clay_15_30 = np.reshape(clay_15_30.read(1)/10,-1)

# sand
sand_15_30 = rasterio.open(path_in + 'sand_15-30_mean.tif')
sand_15_30 = np.reshape(sand_15_30.read(1)/10,-1)

# silt
silt_15_30 = rasterio.open(path_in + 'silt_15-30_mean.tif')
silt_15_30 = np.reshape(silt_15_30.read(1)/10,-1)

# bdod
bdod_15_30 = rasterio.open(path_in + 'bdod_15-30_mean.tif')
bdod_15_30 = np.reshape(bdod_15_30.read(1)/100,-1)

input_data_15_30 = np.vstack((clay_15_30,sand_15_30,silt_15_30,bdod_15_30)).T
input_file = path_in + 'input_data_15_30.txt'
output_file = path_in + 'output_data_15_30.txt'
np.savetxt(input_file, input_data_15_30)
np.savetxt(output_file, np.array([0,0]))

# 30 to 60cm
#clay
clay_30_60 = rasterio.open(path_in + 'clay_30-60_mean.tif')
clay_30_60 = np.reshape(clay_30_60.read(1)/10,-1)

# sand
sand_30_60 = rasterio.open(path_in + 'sand_30-60_mean.tif')
sand_30_60 = np.reshape(sand_30_60.read(1)/10,-1)

# silt
silt_30_60 = rasterio.open(path_in + 'silt_30-60_mean.tif')
silt_30_60 = np.reshape(silt_30_60.read(1)/10,-1)

# bdod
bdod_30_60 = rasterio.open(path_in + 'bdod_30-60_mean.tif')
bdod_30_60 = np.reshape(bdod_30_60.read(1)/100,-1)

input_data_30_60 = np.vstack((clay_30_60,sand_30_60,silt_30_60,bdod_30_60)).T
input_file = path_in + 'input_data_30_60.txt'
output_file = path_in + 'output_data_30_60.txt'
np.savetxt(input_file, input_data_30_60)
np.savetxt(output_file, np.array([0,0]))

# 60 to 100cm
#clay
clay_60_100 = rasterio.open(path_in + 'clay_60-100_mean.tif')
clay_60_100 = np.reshape(clay_60_100.read(1)/10,-1)

# sand
sand_60_100 = rasterio.open(path_in + 'sand_60-100_mean.tif')
sand_60_100 = np.reshape(sand_60_100.read(1)/10,-1)

# silt
silt_60_100 = rasterio.open(path_in + 'silt_60-100_mean.tif')
silt_60_100 = np.reshape(silt_60_100.read(1)/10,-1)

# bdod
bdod_60_100 = rasterio.open(path_in + 'bdod_60-100_mean.tif')
bdod_60_100 = np.reshape(bdod_60_100.read(1)/100,-1)

input_data_60_100 = np.vstack((clay_60_100,sand_60_100,silt_60_100,bdod_60_100)).T
input_file = path_in + 'input_data_60_100.txt'
output_file = path_in + 'output_data_60_100.txt'
np.savetxt(input_file, input_data_60_100)
np.savetxt(output_file, np.array([0,0]))

# 100 to 200cm
#clay
clay_100_200 = rasterio.open(path_in + 'clay_100-200_mean.tif')
clay_100_200 = np.reshape(clay_100_200.read(1)/10,-1)

# sand
sand_100_200 = rasterio.open(path_in + 'sand_100-200_mean.tif')
sand_100_200 = np.reshape(sand_100_200.read(1)/10,-1)

# silt
silt_100_200 = rasterio.open(path_in + 'silt_100-200_mean.tif')
silt_100_200 = np.reshape(silt_100_200.read(1)/10,-1)

# bdod
bdod_100_200 = rasterio.open(path_in + 'bdod_100-200_mean.tif')
bdod_100_200 = np.reshape(bdod_100_200.read(1)/100,-1)

input_data_100_200 = np.vstack((clay_100_200,sand_100_200,silt_100_200,bdod_100_200)).T
input_file = path_in + 'input_data_100_200.txt'
output_file = path_in + 'output_data_100_200.txt'
np.savetxt(input_file, input_data_100_200)
np.savetxt(output_file, np.array([0,0]))

## 30 to 100cm
#clay_30_100 = clay_30_60*3.0/7.0 + clay_60_100*4.0/7.0
#sand_30_100 = sand_30_60*3.0/7.0 + sand_60_100*4.0/7.0
#silt_30_100 = silt_30_60*3.0/7.0 + silt_60_100*4.0/7.0
#bdod_30_100 = bdod_30_60*3.0/7.0 + bdod_60_100*4.0/7.0

#input_data_30_100 = np.vstack((clay_30_100,sand_30_100,silt_30_100,bdod_30_100)).T
#input_file = '../../Data/TXT/Soil_data/input_data_30_100.txt'
#output_file = '../../Data/TXT/Soil_data/output_data_30_100.txt'
#np.savetxt(input_file, input_data_30_100)
#np.savetxt(output_file, np.array([0,0]))

# %% [markdown]
# #### Execute rosetta

# %%
# OUTPUT
# theta_r [cm3/cm3]
# theta_s - porosity [cm3/cm3]
# alpha  [1/cm]
# n
# Ks in [cm/day]

os.system('python3 ../../External_tools/Rosetta_3/Rpredict.py   -i  ../../Data/TXT/Soil_data/input_data_0_5.txt   -o  ../../Data/TXT/Soil_data/output_data_0_5.txt --predict  --sqlite=../../External_tools/Rosetta_3/sqlite/Rosetta.sqlite')
os.system('python3 ../../External_tools/Rosetta_3/Rpredict.py   -i  ../../Data/TXT/Soil_data/input_data_5_15.txt   -o  ../../Data/TXT/Soil_data/output_data_5_15.txt --predict  --sqlite=../../External_tools/Rosetta_3/sqlite/Rosetta.sqlite')
os.system('python3 ../../External_tools/Rosetta_3/Rpredict.py   -i  ../../Data/TXT/Soil_data/input_data_15_30.txt   -o  ../../Data/TXT/Soil_data/output_data_15_30.txt --predict  --sqlite=../../External_tools/Rosetta_3/sqlite/Rosetta.sqlite')
os.system('python3 ../../External_tools/Rosetta_3/Rpredict.py   -i  ../../Data/TXT/Soil_data/input_data_30_60.txt   -o  ../../Data/TXT/Soil_data/output_data_30_60.txt --predict  --sqlite=../../External_tools/Rosetta_3/sqlite/Rosetta.sqlite')
os.system('python3 ../../External_tools/Rosetta_3/Rpredict.py   -i  ../../Data/TXT/Soil_data/input_data_60_100.txt   -o  ../../Data/TXT/Soil_data/output_data_60_100.txt --predict  --sqlite=../../External_tools/Rosetta_3/sqlite/Rosetta.sqlite')
os.system('python3 ../../External_tools/Rosetta_3/Rpredict.py   -i  ../../Data/TXT/Soil_data/input_data_100_200.txt   -o  ../../Data/TXT/Soil_data/output_data_100_200.txt --predict  --sqlite=../../External_tools/Rosetta_3/sqlite/Rosetta.sqlite')
#os.system('python ../../External_tools/Rosetta_3/Rpredict.py   -i  ../../Data/TXT/Soil_data/input_data_30_100.txt   -o  ../../Data/TXT/Soil_data/output_data_30_100.txt --predict  --sqlite=../../External_tools/Rosetta_3/sqlite/Rosetta.sqlite')
# Out:
# python3: can't open file '/home/patras/PF-Valmalenco/scripts/preprocess/../../External_tools/Rosetta_3/Rpredict.py': [Errno 2] No such file or directory
# python3: can't open file '/home/patras/PF-Valmalenco/scripts/preprocess/../../External_tools/Rosetta_3/Rpredict.py': [Errno 2] No such file or directory
# python3: can't open file '/home/patras/PF-Valmalenco/scripts/preprocess/../../External_tools/Rosetta_3/Rpredict.py': [Errno 2] No such file or directory
# python3: can't open file '/home/patras/PF-Valmalenco/scripts/preprocess/../../External_tools/Rosetta_3/Rpredict.py': [Errno 2] No such file or directory
# python3: can't open file '/home/patras/PF-Valmalenco/scripts/preprocess/../../External_tools/Rosetta_3/Rpredict.py': [Errno 2] No such file or directory
# python3: can't open file '/home/patras/PF-Valmalenco/scripts/preprocess/../../External_tools/Rosetta_3/Rpredict.py': [Errno 2] No such file or directory
# 512

# %% [markdown]
# #### Visualize parameters

# %%
ks = np.loadtxt('../../Data/TXT/Lombardy_solid/output_data_30_100.txt', delimiter=',')[:,4]
ks = np.reshape(ks,(165,265))

plt.imshow(ks)
plt.colorbar()
